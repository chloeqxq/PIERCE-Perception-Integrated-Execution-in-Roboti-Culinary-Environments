# %%
import cv2
import matplotlib.pyplot as plt
# Example path for a specific Logitech webcam
paths = [
    # "/dev/v4l/by-path/pci-0000:c1:00.3-usbv2-0:2.2:1.0-video-index0",
    # "/dev/v4l/by-path/pci-0000:c1:00.3-usbv2-0:2.1:1.0-video-index0",
    "/dev/v4l/by-path/pci-0000:c1:00.3-usbv2-0:2.2:1.0-video-index0",
    "/dev/v4l/by-id/usb-Generic_Laptop_Camera_200901010001-video-index0"
        #  "/dev/v4l/by-id/usb-lihappe8_Corp._USB_2.0_Camera-video-index0"
         
         ]
caps = []
for path in paths:
    cap = cv2.VideoCapture(path, cv2.CAP_V4L2)
    caps.append(cap)
# # Set buffer size to 1 to minimize lag
# cap.set(cv2.CAP_PROP_BUFFERSIZE, 1)

# # Check if the property was set correctly
# buffer_size = cap.get(cv2.CAP_PROP_BUFFERSIZE)
# print(f"Current buffer size: {buffer_size}")

# %%
success,arr = caps[1].read()
print(f"status: {success}")
plt.imshow(arr)
# Out:
# status: True
